# %% [markdown]
# <h1 style="color: lightseagreen;">Neurons</h1>
#
#
# for now **Neuron** -> Thing that holds a number
#
# <img src="images/Screenshot (164).png">
#
# all of these 784 Neurons make the first layer of our neural network
#
# <img src="images/Screenshot (165).png">
#
# the last layer has 10 neurons the activations of these neurons (0 ~ 1), how much does it correspond with a given digit
#
# <img src="images/Screenshot (166).png"><br>
#
# <img src="images/Screenshot (167).png"><br>
#
# <img src="images/Screenshot (168).png"><br>
#
# <img src="images/Screenshot (169).png">
#
# How those activation sequencing ?
#
# the brightest neuron will be choosen
#
#
# the model can identify somethin using subcomponents, we hope that these subcomponents will match.
#
# what parameters should the network have ?
#
# we will assign a weights to each of the connections and the neurons of<br> the first layers (These weights are just numbers),
# then take all those activations and<br> compute their wieghted sum according to these weights.
#
# <img src="images/Screenshot (170).png">
#
# <img src="images/Screenshot (171).png">
#
# for this network we won't the activations to be subavalues (0 ~ 1).
#
# <img src="images/Screenshot (172).png">
#
# commonn method is to push that weighted sum into sum function that make them in this range.
#
# common function: sigmoid
#
# <img src="images/Screenshot (173).png">
#
# the activation is measured how positive the relevent weighted sum is.
#
# but maybe we don't won't the neuron to light simply when the weighted sum is bigger than 0.
#
# <img src="images/Screenshot (175).png">
#
# for example only active when weighted sum is > 10. do we need a bias.
#
# <img src="images/Screenshot (174).png">
#
# each neurons have a bias.
#
# <img src="images/Screenshot (177).png">
#
#
# to orginize all the activators of 1 layers into a vector then organize all<br> the weights as a matrix, each row correspond to the connection between one layer <br>and a particular neuron on the next layer.
#
# <img src="images/Screenshot (178).png">
# <img src="images/Screenshot (179).png"><br>
# <img src="images/Screenshot (180).png">
#
# now for the bias we organize it in a matrix and add it to the previous vector matrix product,
# the we wrapp sigmoid arround the outside.
#
# <img src="images/Screenshot (181).png">
#
# <img src="images/Screenshot (182).png"><br>
#
# <img src="images/Screenshot (183).png">
#
# <img src="images/Screenshot (184).png">
#
# <h2 style="color: lightseagreen">So the network an the neurons is actually a function.<h2>
#
# <img src="images/Screenshot (185).png">
#
# <h2 style="color: lightseagreen">Attention</h2>
#
# sigmoid is rarely used now (old school), `ReLU(a) = max(0, a)`
# when neurons pass a certain threshhold, it will be activated
#
# <img src="images/Screenshot (186).png">
#
# <img src="images/Screenshot (187).png">
#
# <style>
#     img {
#         width: 400px;
#         height: 310px;
#         border: 1px solid lightseagreen;
#     }
# </style>
