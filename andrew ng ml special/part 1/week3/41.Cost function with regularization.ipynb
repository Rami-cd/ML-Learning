# %% [markdown]
# <h1>Cost function with regularization</h1>
#
# <style>
#     h1{
#         color: lightseagreen;
#         width: 100%;
#         text-align: center;
#     }
# </style>

# %% [markdown]
# now we will make a modified cost function to apply reglarzation.
#
# <img src="images/108.png">
#
# so what we did here we gave w3 and w4 large values so when we minimize this function we end up with w3 and w4 close to 0.
#
# now it's a much better fot the data so it don't end up squiggly and overfitting.
#
# <img src="images/109.png">
#
# we regularize w3 and w4 (penalize), this make the function smoother less wiggly.
#
# here we have 100 parameter, and we don't know which ones are the important ones.
#
# the lambda here is the ***regularization parameter***, we divide both equation by `2m` to make it easier to find lambda.
#
# also by convetient we don't penalize `b` for being large.
#
# some models do so (add lambda over 2m * $b^{2}$) but it make so little difference.
#
# <img src="images/110.png">
#
# so to Summarize in this new function we want to minimize the original cost, which the mean squarred error with the second term called the ***regularization term***.
#
#
# so this function minimize the cost and minimize the ***regularization term*** to reduce overfitting, lambda balance these 2 goals.
#
# if λ = 0 the function will overfitt.
#
# if λ = 10,000 (very large), then we are placing very heavy weight on the regularization, and to regularize this the weights should be very close to 0.
#
# so the alg choose the weights to be close to 0, so f(x) = b, so it make a horizontal straigh line and it underfit.
#
# so choose λ to balance the 2 terms.
#
# <h2>Regularized linear regression</h2>
#
# <img src="images/110.png">
#
# this is the new definition.
#
# <img src="images/111.png">
#
# to implement it those are the updates for all the parameter, the code will do it simulatneous.
#
# more (math)
#
#
#
# <h2>Regularized logistic regression</h2>
#
# <img src="images/112.png">
#
# here z is overfitting, we use regularization term to make it fit well.
#
# <img src="images/113.png">
#
#
#
# <style>
#     img {
#         width: 500px;
#         height: 340px;
#         border: 1px solid lightseagreen;
#         border-radius: 10px;
#     }
#     h2 {
#         margin-left: 20px;
#         color: lightseagreen;
#     }
# </style>
