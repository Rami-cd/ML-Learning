# %% [markdown]
# <h1>Multiple features</h1>
#
# <style>
#     h1{
#         color: lightseagreen;
#         width: 100%;
#         text-align: center;
#     }
# </style>

# %% [markdown]
# In the original we have a single feature x and we are able to predict y,
#
# <img src="images/57.png">
#
# but now what if we have multiple features
#
# <img src="images/58.png">
#
# now we're going to use $x_{1}$, $x_{2}$, $x_{3}$ ...
#
# n is the number of features.
#
# the last is a vector of the rows that contain the features, the number below it show which index in the vector.
#
#
# let's take a look how the model looks like
#
# <img src="images/59.png">
#
# here again is the def of the model with n features
#
# <img src="images/60.png">
#
# w is a row vector
#
# w and b are the parameters
#
# the name of this model is ***multiple linear regression***
#
# <h2>Quiz</h2>
#
# <img src="images/61.png">
# <img src="images/62.png">
#
# the answer `852`
#
# <style>
#     img {
#         width: 500px;
#         height: 340px;
#         border: 1px solid lightseagreen;
#         border-radius: 10px;
#     }
#     h2 {
#         margin-left: 20px;
#         color: lightseagreen;
#     }
# </style>

# %% [markdown]
# <h2>Vectorization part 1</h2>
#
# make the code shorter, and make it run much more efficiently.
#
# <img src="images/63.png">
#
# the first 2 implementations are not efficient
#
# the 3rd has 2 benefit less code and faster, it is faster because the numpy dot function is able to use parallel hradware in a computer, for both cpu and gpu.
#
# <h2>Vectorization part 2</h2>
#
# how vectrized implementation work
#
# in a for loop it is performed one by one, the dot function the computer get all values of w and x at the same time in parallel, then the computer use specialized hardware to add them all together.
#
# <img src="images/64.png">
#
# how this helps ***multiple linear regression*** ?
#
# <img src="images/65.png">
#
#
# <style>
#     img {
#         width: 500px;
#         height: 340px;
#         border: 1px solid lightseagreen;
#         border-radius: 10px;
#     }
#     h2 {
#         margin-left: 20px;
#         color: lightseagreen;
#     }
# </style>
