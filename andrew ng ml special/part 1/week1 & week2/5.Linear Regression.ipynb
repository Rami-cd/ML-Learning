# %% [markdown]
# <h1>Linear Regression<br>with One variable</h1>
#
# <style>
#     h1{
#         color: lightseagreen;
#         width: 100%;
#         text-align: center;
#     }
# </style>

# %% [markdown]
# <h2>Problem</h2>
#
# <img src="images/15.png">
#
# each of the crosses is a house with size and a price.
#
# This type of supervised learning model is called a ***Regression model***, because it predict continious number as output.
#
# a ***Classification model*** predict categories, example(cat ot dog), there is a small number of possible outputs.
#
# one way to look at the data is a data table
#
# <img src="images/16.png">
#
# each cross correspond to one row of the table.
#
# Let's look at some notations describing the data
#
# <h2>How supervised learning work</h2>
#
# the function used to be calles hypothesis (not here).
#
# the job of f to take new input x and ouptput y and estimate the *y-hat*.
#
# **f -> model**
# **x -> feature**
# **y -> prediction**
#
# y is an estimate may be false.
#
# <h2>How to represent f</h2>
#
# <img src="images/17.png">
#
# the values of *w* and *b* determined to predict *y-hat*
#
# but why linear function ?
#
# as a fundation for now
#
# <p style="color: lightgreen">y is the target, the actual true value in the training set, but Y-hat is the estimate(may or may not be true).</p>
#
# <h2>Quiz</h2>
#
# <img src="images/18.png">
#
#
#
# <style>
#     img {
#         width: 600px;
#         height: 400px;
#         border: 1px solid lightseagreen;
#         border-radius: 10px;
#     }
#     h2 {
#         margin-left: 20px;
#         color: lightseagreen;
#     }
# </style>
