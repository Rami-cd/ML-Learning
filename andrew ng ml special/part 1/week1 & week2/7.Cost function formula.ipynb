# %% [markdown]
# <h1>Cost function formula</h1>
#
# <style>
#     h1{
#         color: lightseagreen;
#         width: 100%;
#         text-align: center;
#     }
# </style>

# %% [markdown]
# The cost function tells us how well the model is doing, and try to get it to do better
#
# you can adjust `w` and `b` in the training.
#
# <img src="images/19.png">
#
# when w = 0 `f` is constant, it's a straight line.
#
# w is the slope of the line, b move the line.
#
# <img src="images/21.png">
#
# with linear regression, we need to choose values for `w` and `b` so the straight line fit the data well.
#
# <img src="images/22.png">
#
# How to find values for `w` and `b` so the prediction `ŷ` is close to the true target `y` for all the training examples.
#
# <h2>Cost function</h2>
#
# m is the number of training examples, with more training examples m is larger, and the cost function will calculate a bigger number, so to build a cost function that doesn't automatically get bigger as the training set gets larger, by convention we conputes the average square error instead of the total square error by dividing by 2m (we can without the 2, it's here to make the calculation easyer)
#
# <img src="images/23.png">
#
#
# <h2>Cost Function Intuition</h2>
#
# <img src="images/24.png">
#
# here the cost function with a simplified verion.
#
# for *$f_{w}$(x)* when the parameter *w* is fixed then *$f_{w}$* is a function of *x*, int contrast *j(w)* is a function of *w* that control the slope of the line, so it depend on a parameter *w*.
#
# here with *w* = 1
#
# <img src="images/25.png">
#
# What if *w* is 0.5
#
# <img src="images/26.png">
#
# for w = 0 then f(x) is just a straight line, if w is negative the line will be going downward and we have a higher cost.
#
# <img src="images/27.png">
#
# we get how J looks like.
#
# <h2>Question</h2>
#
# <img src="images/28.png">
#
# <h2>Visualizing the cost function</h2>
#
# Overall look:
#
# <img src="images/29.png">
#
# before we took b=0 to simplify but now we will take it as it is.
#
# <img src="images/30.png">
#
# the cost function has a similar shape in 3d.
#
# <img src="images/31.png">
#
# any single point on this surface represent a particular point for example if w = -15 and b = -15 the height is J(w = -10, b = -15)
#
# another way to plot this function
#
# <img src="images/32.png">
# <img src="images/33.png">
#
# at the bottom here there is a 3d surface plot of the cost function J, it's bow shape.
#
# in the upper-right is a contour example of this cost function, if you slice it horizontally you get the points that are the same heights, what each of these ellipses shows is the set of points on the 3d surface with the exact same height, meaning same J, the ellipse at the center is the minumum of the constant function.
#
# <img src="images/34.png">
#
#
#
# <h2>Visualization examples</h2>
#
# <img src="images/35.png">
#
# the line doesn't fit the data well, its pretty far from the minimum.
# <br>
#
# <img src="images/36.png">
#
# this example doesn't fit the data well but it's slightly better than the previous one.
#
# <img src="images/37.png">
#
# this example is even more far than the minimum.
#
# <img src="images/38.png">
#
# this is a pretty good fit to the training set.
#
#
# <style>
#     img {
#         width: 600px;
#         height: 400px;
#         border: 1px solid lightseagreen;
#         border-radius: 10px;
#     }
#     h2 {
#         margin-left: 20px;
#         color: lightseagreen;
#     }
# </style>
